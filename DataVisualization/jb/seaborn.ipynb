# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
sns.set(style='darkgrid')

# %matplotlib inline

# %%
# 데이터셋
tips = sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x='total_bill', y = 'tip', data = tips)

# %%
# hue 색상 - 범주형
sns.relplot(x = 'total_bill', y = 'tip', data = tips, hue = 'smoker')

# %%
# style -  hue 색상 - 수치형
sns.relplot(x='total_bill', y = 'tip', data = tips, style = 'smoker', hue = 'size')

# %% [markdown]
# 참고 사이트 : https://seaborn.pydata.org/tutorial/color_palettes.html

# %%
# 색상
sns.relplot(x = 'total_bill', y = 'tip', data = tips, hue = 'size', palette='Blues')

# %%
df = pd.DataFrame(dict(time=np.arange(500), value=np.random.randn(500).cumsum()))

# %%
df
# Out:
#      time      value
# 0       0   0.053400
# 1       1  -0.113234
# 2       2   0.433668
# 3       3   0.937362
# 4       4  -0.056706
# ..    ...        ...
# 495   495 -18.768609
# 496   496 -17.289393
# 497   497 -15.863328
# 498   498 -15.885413
# 499   499 -15.976307
#
# [500 rows x 2 columns]

# %%
sns.relplot(x = 'time', y = 'value', data = df, kind = 'line')

# %%
fmri = sns.load_dataset('fmri')

# %%
fmri
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
sns.relplot(x = 'timepoint', y = 'signal', kind = 'line', data = fmri, ci = None)

# %%
# ci 가 없을 경우 -> 표준편차

sns.relplot(x = 'timepoint', y = 'signal', kind = 'line', data = fmri)

# %%
# ci = 'sd' 분산

sns.relplot(x = 'timepoint', y = 'signal', kind = 'line', data = fmri, ci = 'sd')

# %%
sns.relplot(x = 'timepoint', y = 'signal', kind = 'line', data = fmri, ci = 'sd', hue = 'region', style = 'event')

# %%
# cat plot
sns.catplot(x = 'day', y = 'total_bill', data = tips) # 요일 별 요금 정산

# %%
sns.catplot(x = 'day', y = 'total_bill', data = tips, kind = 'box')

# %%
sns.catplot(x = 'day', y = 'total_bill', data = tips, kind = 'violin')

# %%
sns.catplot(x = 'day', y = 'total_bill', data = tips, kind = 'boxen')

# %%
sns.catplot(x = 'day', y = 'total_bill', data = tips, kind = 'count')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-fa3b840f9560> in <module>()
# ----> 1 sns.catplot(x = 'day', y = 'total_bill', data = tips, kind = 'count')
#
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py in catplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, seed, order, hue_order, row_order, col_order, kind, height, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3710             x_, y_, orient = x, x, "v"
#    3711         else:
# -> 3712             raise ValueError("Either `x` or `y` must be None for count plots")
#    3713     else:
#    3714         x_, y_ = x, y
#
# ValueError: Either `x` or `y` must be None for count plots

# %%
sns.catplot(x = 'day', y = 'total_bill', data = tips, kind = 'bar')

# %%
sns.catplot(x = 'day', y = 'total_bill', data = tips, kind = 'point')

# %%
sns.catplot(x = 'day', y = 'total_bill', data = tips, kind = 'swarm', hue = 'sex')

# %%
sns.catplot(x = 'day', y = 'total_bill', data = tips, kind = 'violin', inner = 'stick', split = True,  hue = 'sex')

# %%
titanic = sns.load_dataset('titanic')

# %%
sns.catplot(x = 'sex', y = 'survived', hue = 'class', kind = 'bar', data = titanic)

# %%
df = pd.DataFrame(np.random.randn(500, 2), columns = ['1', '2'])

# %%
df
# Out:
#             1         2
# 0    0.538447  0.706847
# 1    0.058848  0.647208
# 2   -0.544342  1.182896
# 3    1.401954  0.332670
# 4    0.092954 -1.748947
# ..        ...       ...
# 495 -0.805062  0.255615
# 496  1.022066  0.513064
# 497 -0.581365 -0.803281
# 498 -1.052909 -1.230966
# 499  0.560406  0.686155
#
# [500 rows x 2 columns]

# %%
sns.relplot(data = df, x = '1', y = '2')

# %%
sns.jointplot(data = df, x = '1', y = '2')

# %%
sns.jointplot(data = df, x = '1', y = '2', kind = 'hex')

# %%
sns.jointplot(data = df, x = '1', y = '2', kind = 'kde')

# %%
sns.jointplot(data = df, x = '1', y = '2', kind = 'resid')

# %%
sns.jointplot(data = df, x = '1', y = '2', kind = 'reg')
