# %%
# %pylab inline
import numpy as np
import pandas as pd
from tabulate import tabulate
import os
from ipypublish import nb_setup
from IPython.display import Image
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# #  제1주

# %% [markdown]
# # 1. 경제 및 금융 관련 빅데이터 입수하기

# %% [markdown]
# * 빅데이터는 주로 web에서 구할 수 있음
#
#
# * 다양한 데이터 출처가 있지만 이번 수업에서는 공공데이터포털, Naver에서 주가데이터 구하는 실습을 하고자 함

# %% [markdown]
# ## 1.1 공공데이타 포털

# %%
https://www.data.go.kr/

# %% [markdown]
# 1. 공공데이터포털에 들어가기

# %%
nb_setup.images_hconcat(['C:/HSCHUNG/PYTHON/B_CLASS/A_BigDataEconomics/C202101/png/W01_0302/공공데이터포털01.png'], width=800)
# Out:
# <PIL.Image.Image image mode=RGBA size=800x483 at 0x1FA495EAD30>

# %% [markdown]
# 2. 회원가입하기

# %%
nb_setup.images_hconcat(['C:/HSCHUNG/PYTHON/B_CLASS/A_BigDataEconomics/C202101/png/W01_0302/공공데이터포털02.png'], width=800)
# Out:
# <PIL.Image.Image image mode=RGBA size=800x491 at 0x1FA495D9E80>

# %% [markdown]
# 3,로그인하기

# %%
nb_setup.images_hconcat(['C:/HSCHUNG/PYTHON/B_CLASS/A_BigDataEconomics/C202101/png/W01_0302/공공데이터포털03.png'], width=800)
# Out:
# <PIL.Image.Image image mode=RGBA size=800x537 at 0x1FA4C4A4E80>

# %% [markdown]
# [3.주요 데이터 목록](https://www.data.go.kr/tcs/dss/selectDataSetList.do?dType=API&keyword=&detailKeyword=&publicDataPk=&recmSe=&detailText=&relatedKeyword=&commaNotInData=&commaAndData=&commaOrData=&must_not=&tabId=&dataSetCoreTf=&coreDataNm=&sort=&relRadio=&orgFullName=&orgFilter=&org=&orgSearch=&currentPage=2&perPage=10&brm=&instt=&svcType=&kwrdArray=&extsn=&coreDataNmArray=&pblonsipScopeCode=)

# %%
nb_setup.images_hconcat(['C:/HSCHUNG/PYTHON/B_CLASS/A_BigDataEconomics/C202101/png/W01_0302/공공데이터포털04.png'], width=800)
# Out:
# <PIL.Image.Image image mode=RGBA size=800x453 at 0x1FA4C4A4D60>

# %% [markdown]
# [4.국토교통부 실거래가 정보](https://www.data.go.kr/data/15058747/openapi.do)

# %%
nb_setup.images_hconcat(['C:/HSCHUNG/PYTHON/B_CLASS/A_BigDataEconomics/C202101/png/W01_0302/공공데이터포털05.png'], width=800)
# Out:
# <PIL.Image.Image image mode=RGBA size=800x434 at 0x1FA4C4A4EE0>

# %% [markdown]
# 활용신청

# %%
nb_setup.images_hconcat(['C:/HSCHUNG/PYTHON/B_CLASS/A_BigDataEconomics/C202101/png/W01_0302/공공데이터포털06.png'], width=800)
# Out:
# <PIL.Image.Image image mode=RGBA size=800x453 at 0x1FA4C4A4C10>

# %% [markdown]
# 인증키 발급 현황 확인

# %%
nb_setup.images_hconcat(['C:/HSCHUNG/PYTHON/B_CLASS/A_BigDataEconomics/C202101/png/W01_0302/공공데이터포털07.png'], width=800)
# Out:
# <PIL.Image.Image image mode=RGBA size=800x236 at 0x1FA4C4A4880>
