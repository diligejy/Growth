# %% [markdown]
# #  제2장

# %% [markdown]
# # 1. Pandas

# %% [markdown]
# ### 3.1.1 : Series and DataFrame

# %%
import pandas as pd

# %%
df = pd.read_csv('house_price.csv')

# %%
df
# Out:
#      Unnamed: 0  year  month  day    price  built_yr dong_name  \
# 0             0  2021      6    1  150,000      1988       방배동
# 1             1  2021      6    1  155,000      2003       방배동
# 2             2  2021      6    2  290,000      1983       방배동
# 3             3  2021      6    2  210,000      2006       방배동
# 4             4  2021      6    2  175,000      1992       방배동
# ..          ...   ...    ...  ...      ...       ...       ...
# 191         191  2021      6   24  147,000      2014       내곡동
# 192         192  2021      6   28  160,000      2014       내곡동
# 193         193  2021      6    3  192,500      2014       신원동
# 194         194  2021      6    3  192,500      2014       신원동
# 195         195  2021      6   11  185,000      2014       신원동
#
#            apt_name    size  gu_code
# 0              방배임광   82.34    11650
# 1    삼환나띠르빌(1002-9)  148.99    11650
# 2             방배신삼호  185.46    11650
# 3            롯데캐슬헤론  169.08    11650
# 4            대우(효령)   84.91    11650
# ..              ...     ...      ...
# 191          서초더샵포레   59.69    11650
# 192          서초더샵포레   84.81    11650
# 193       서초포레스타5단지  101.35    11650
# 194       서초포레스타5단지  101.35    11650
# 195       서초포레스타5단지   84.41    11650
#
# [196 rows x 10 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'year', 'month', 'day', 'price', 'built_yr', 'dong_name',
#        'apt_name', 'size', 'gu_code'],
#       dtype='object')

# %%
df = df.drop('Unnamed: 0', axis=1) # 0 row, 1 column

# %%
df
# Out:
#      year  month  day    price  built_yr dong_name        apt_name    size  \
# 0    2021      6    1  150,000      1988       방배동            방배임광   82.34
# 1    2021      6    1  155,000      2003       방배동  삼환나띠르빌(1002-9)  148.99
# 2    2021      6    2  290,000      1983       방배동           방배신삼호  185.46
# 3    2021      6    2  210,000      2006       방배동          롯데캐슬헤론  169.08
# 4    2021      6    2  175,000      1992       방배동          대우(효령)   84.91
# ..    ...    ...  ...      ...       ...       ...             ...     ...
# 191  2021      6   24  147,000      2014       내곡동          서초더샵포레   59.69
# 192  2021      6   28  160,000      2014       내곡동          서초더샵포레   84.81
# 193  2021      6    3  192,500      2014       신원동       서초포레스타5단지  101.35
# 194  2021      6    3  192,500      2014       신원동       서초포레스타5단지  101.35
# 195  2021      6   11  185,000      2014       신원동       서초포레스타5단지   84.41
#
#      gu_code
# 0      11650
# 1      11650
# 2      11650
# 3      11650
# 4      11650
# ..       ...
# 191    11650
# 192    11650
# 193    11650
# 194    11650
# 195    11650
#
# [196 rows x 9 columns]

# %%
df[2:4] # row slicing
# Out:
#    year  month  day    price  built_yr dong_name apt_name    size  gu_code
# 2  2021      6    2  290,000      1983       방배동    방배신삼호  185.46    11650
# 3  2021      6    2  210,000      2006       방배동   롯데캐슬헤론  169.08    11650

# %%
df[['price', 'size']]
# Out:
#        price    size
# 0    150,000   82.34
# 1    155,000  148.99
# 2    290,000  185.46
# 3    210,000  169.08
# 4    175,000   84.91
# ..       ...     ...
# 191  147,000   59.69
# 192  160,000   84.81
# 193  192,500  101.35
# 194  192,500  101.35
# 195  185,000   84.41
#
# [196 rows x 2 columns]

# %%
col = ['price', 'size']

# %%
df[col]
# Out:
#        price    size
# 0    150,000   82.34
# 1    155,000  148.99
# 2    290,000  185.46
# 3    210,000  169.08
# 4    175,000   84.91
# ..       ...     ...
# 191  147,000   59.69
# 192  160,000   84.81
# 193  192,500  101.35
# 194  192,500  101.35
# 195  185,000   84.41
#
# [196 rows x 2 columns]

# %% [markdown]
# To select both rows and columns using integers, the iloc attribute should be used with the
# format .iloc[rows, columns]

# %%
df.iloc[2:5, 0:2]
# Out:
#    year  month
# 2  2021      6
# 3  2021      6
# 4  2021      6

# %%
df.loc[df.index[2:5], ['size', 'price']]
# Out:
#      size    price
# 2  185.46  290,000
# 3  169.08  210,000
# 4   84.91  175,000

# %%
df
# Out:
#      year  month  day    price  built_yr dong_name        apt_name    size  \
# 0    2021      6    1  150,000      1988       방배동            방배임광   82.34
# 1    2021      6    1  155,000      2003       방배동  삼환나띠르빌(1002-9)  148.99
# 2    2021      6    2  290,000      1983       방배동           방배신삼호  185.46
# 3    2021      6    2  210,000      2006       방배동          롯데캐슬헤론  169.08
# 4    2021      6    2  175,000      1992       방배동          대우(효령)   84.91
# ..    ...    ...  ...      ...       ...       ...             ...     ...
# 191  2021      6   24  147,000      2014       내곡동          서초더샵포레   59.69
# 192  2021      6   28  160,000      2014       내곡동          서초더샵포레   84.81
# 193  2021      6    3  192,500      2014       신원동       서초포레스타5단지  101.35
# 194  2021      6    3  192,500      2014       신원동       서초포레스타5단지  101.35
# 195  2021      6   11  185,000      2014       신원동       서초포레스타5단지   84.41
#
#      gu_code
# 0      11650
# 1      11650
# 2      11650
# 3      11650
# 4      11650
# ..       ...
# 191    11650
# 192    11650
# 193    11650
# 194    11650
# 195    11650
#
# [196 rows x 9 columns]

# %%
df2 = df.set_index('dong_name')

# %%
df2
# Out:
#            year  month  day    price  built_yr        apt_name    size  \
# dong_name
# 방배동        2021      6    1  150,000      1988            방배임광   82.34
# 방배동        2021      6    1  155,000      2003  삼환나띠르빌(1002-9)  148.99
# 방배동        2021      6    2  290,000      1983           방배신삼호  185.46
# 방배동        2021      6    2  210,000      2006          롯데캐슬헤론  169.08
# 방배동        2021      6    2  175,000      1992          대우(효령)   84.91
# ...         ...    ...  ...      ...       ...             ...     ...
# 내곡동        2021      6   24  147,000      2014          서초더샵포레   59.69
# 내곡동        2021      6   28  160,000      2014          서초더샵포레   84.81
# 신원동        2021      6    3  192,500      2014       서초포레스타5단지  101.35
# 신원동        2021      6    3  192,500      2014       서초포레스타5단지  101.35
# 신원동        2021      6   11  185,000      2014       서초포레스타5단지   84.41
#
#            gu_code
# dong_name
# 방배동          11650
# 방배동          11650
# 방배동          11650
# 방배동          11650
# 방배동          11650
# ...            ...
# 내곡동          11650
# 내곡동          11650
# 신원동          11650
# 신원동          11650
# 신원동          11650
#
# [196 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 196 entries, 0 to 195
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   year       196 non-null    int64
#  1   month      196 non-null    int64
#  2   day        196 non-null    int64
#  3   price      196 non-null    object
#  4   built_yr   196 non-null    int64
#  5   dong_name  196 non-null    object
#  6   apt_name   196 non-null    object
#  7   size       196 non-null    float64
#  8   gu_code    196 non-null    int64
# dtypes: float64(1), int64(5), object(3)
# memory usage: 13.9+ KB

# %%
df['price']=df['price'].str.replace(',', '').astype(int)

# %%
df.head()
# Out:
#    year  month  day   price  built_yr dong_name        apt_name    size  \
# 0  2021      6    1  150000      1988       방배동            방배임광   82.34
# 1  2021      6    1  155000      2003       방배동  삼환나띠르빌(1002-9)  148.99
# 2  2021      6    2  290000      1983       방배동           방배신삼호  185.46
# 3  2021      6    2  210000      2006       방배동          롯데캐슬헤론  169.08
# 4  2021      6    2  175000      1992       방배동          대우(효령)   84.91
#
#    gu_code
# 0    11650
# 1    11650
# 2    11650
# 3    11650
# 4    11650

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 196 entries, 0 to 195
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   year       196 non-null    int64
#  1   month      196 non-null    int64
#  2   day        196 non-null    int64
#  3   price      196 non-null    int32
#  4   built_yr   196 non-null    int64
#  5   dong_name  196 non-null    object
#  6   apt_name   196 non-null    object
#  7   size       196 non-null    float64
#  8   gu_code    196 non-null    int64
# dtypes: float64(1), int32(1), int64(5), object(2)
# memory usage: 13.1+ KB

# %%
df['size_pyung'] = df['size']/3.33

# %%
df
# Out:
#      year  month  day   price  built_yr dong_name        apt_name    size  \
# 0    2021      6    1  150000      1988       방배동            방배임광   82.34
# 1    2021      6    1  155000      2003       방배동  삼환나띠르빌(1002-9)  148.99
# 2    2021      6    2  290000      1983       방배동           방배신삼호  185.46
# 3    2021      6    2  210000      2006       방배동          롯데캐슬헤론  169.08
# 4    2021      6    2  175000      1992       방배동          대우(효령)   84.91
# ..    ...    ...  ...     ...       ...       ...             ...     ...
# 191  2021      6   24  147000      2014       내곡동          서초더샵포레   59.69
# 192  2021      6   28  160000      2014       내곡동          서초더샵포레   84.81
# 193  2021      6    3  192500      2014       신원동       서초포레스타5단지  101.35
# 194  2021      6    3  192500      2014       신원동       서초포레스타5단지  101.35
# 195  2021      6   11  185000      2014       신원동       서초포레스타5단지   84.41
#
#      gu_code  size_pyung
# 0      11650   24.726727
# 1      11650   44.741742
# 2      11650   55.693694
# 3      11650   50.774775
# 4      11650   25.498498
# ..       ...         ...
# 191    11650   17.924925
# 192    11650   25.468468
# 193    11650   30.435435
# 194    11650   30.435435
# 195    11650   25.348348
#
# [196 rows x 10 columns]

# %%
df['price_pyung'] = df['price']/df['size_pyung']

# %%
df.head()
# Out:
#    year  month  day   price  built_yr dong_name        apt_name    size  \
# 0  2021      6    1  150000      1988       방배동            방배임광   82.34
# 1  2021      6    1  155000      2003       방배동  삼환나띠르빌(1002-9)  148.99
# 2  2021      6    2  290000      1983       방배동           방배신삼호  185.46
# 3  2021      6    2  210000      2006       방배동          롯데캐슬헤론  169.08
# 4  2021      6    2  175000      1992       방배동          대우(효령)   84.91
#
#    gu_code  size_pyung  price_pyung
# 0    11650   24.726727  6066.310420
# 1    11650   44.741742  3464.326465
# 2    11650   55.693694  5207.052734
# 3    11650   50.774775  4135.911994
# 4    11650   25.498498  6863.149217
