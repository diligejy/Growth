# %%
# pip install ipypublish

# %%
import numpy as np
import pandas as pd
from ipypublish import nb_setup

# %% [markdown]
# ## <font color=blue> 주식시장 정보 구하기

# %% [markdown]
# 1. 한국거래소/정보데이터시스템<br> http://www.krx.co.kr/main/main.jsp
# 2. 네이버/증권<br>https://finance.naver.com/
# 3. 금융감독원 전자공시시스템<br> http://dart.fss.or.kr
# 3. 개인 공유 정보

# %% [markdown]
# ## <font color=blue> 1 거래소종목파악하기

# %% [markdown]
# 한국거래소에서 거래되는 주식종목 파악하기
#
#
# http://data.krx.co.kr/contents/MDC/MAIN/main/index.cmd

# %%
nb_setup.images_hconcat(['Z:\B01_HSCHUNG\PYTHON\B_CLASS\A_BigDataEconomics\C202201\png\W03_0316/거래소01.png'], width=600)
# Out:
# <PIL.Image.Image image mode=RGBA size=600x316 at 0x19E1A6E6EB0>

# %% [markdown]
# kind
# KRX 정보데이터시스템<br>
# 주식/종목정보<br>
# 증권상품/ETF/전종목기본정보<br>
# 증권상품/ETN/전종목기본정보<br>

# %% [markdown]
# EXCEL로 자료 받기, html -- excel로 받기

# %%
import pandas as pd 

stock_list = pd.read_excel('stock_list.xlsx')

# %%
stock_list.head()
# Out:
#            표준코드    단축코드        한글 종목명  한글 종목약명  \
# 0  KR7098120009  098120  (주)마이크로컨텍솔루션  마이크로컨텍솔
# 1  KR7131100000  131100     (주)스카이이앤엠   스카이이앤엠
# 2  KR7009520008  009520      (주)포스코엠텍    포스코엠텍
# 3  KR7095570008  095570     AJ네트웍스보통주   AJ네트웍스
# 4  KR7006840003  006840      AK홀딩스보통주    AK홀딩스
#
#                             영문 종목명         상장일    시장구분 증권구분          소속부 주식종류  \
# 0  Micro Contact Solution Co.,Ltd.  2008/09/23  KOSDAQ   주권        벤처기업부  보통주
# 1                SKY E&M Co., Ltd.  2011/06/14  KOSDAQ   주권  관리종목(소속부없음)  보통주
# 2            POSCO M-TECH CO.,LTD.  1997/11/10  KOSDAQ   주권        우량기업부  보통주
# 3             AJ Networks Co.,Ltd.  2015/08/21   KOSPI   주권          NaN  보통주
# 4                AK Holdings, Inc.  1999/08/11   KOSPI   주권          NaN  보통주
#
#     액면가     상장주식수
# 0   500   8312766
# 1   500  11642629
# 2   500  41642703
# 3  1000  46822295
# 4  5000  13247561

# %%
# 우리가 필요한 것은 회사명과 종목코드이기 때문에 필요없는 column들은 제외해준다. 
df = stock_list[['한글 종목명', '단축코드']] # 한글로된 컬럼명을 영어로 바꿔준다.

# %%
df.tail()
# Out:
#                 한글 종목명    단축코드
# 2603  흥국화재해상보험2우선주(신형)  000547
# 2604       흥국화재해상보험보통주  000540
# 2605           흥아해운보통주  003280
# 2606        희림종합건축사사무소  037440
# 2607                힘스  238490

# %%
df[df["한글 종목명"].isin(["삼성전자보통주"])]  # 데이터중 한글종목명이 삼성전자 보통주인 데이터를 불러옵니다.
# Out:
#       한글 종목명    단축코드
# 836  삼성전자보통주  005930
