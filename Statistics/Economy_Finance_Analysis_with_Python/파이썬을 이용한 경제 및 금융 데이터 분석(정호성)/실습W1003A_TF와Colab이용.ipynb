# %%
import tensorflow as tf

# %%
import pandas as pd

# %%
tf.__version__

# %% [markdown]
# https://colab.research.google.com/notebooks/io.ipynb

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %%
df = pd.read_csv('/content/gdrive/MyDrive/HPI_SEOUL.csv', encoding='CP949')

# %%
df.tail()
