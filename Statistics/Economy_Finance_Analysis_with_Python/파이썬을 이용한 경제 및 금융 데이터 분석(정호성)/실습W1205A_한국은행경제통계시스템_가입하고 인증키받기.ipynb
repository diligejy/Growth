# %% [markdown]
# #  제12주

# %%
# %matplotlib inline
import numpy as np 
import matplotlib.pyplot as plt 
import pandas as pd
import os
from ipypublish import nb_setup

# %% [markdown]
# ##  한국은행 경제통계시스템

# %% [markdown]
# https://ecos.bok.or.kr/

# %%
nb_setup.images_hconcat(['C:/HSCHUNG/PYTHON/B_CLASS/B_AppliedDataAnalysis/C202102/PNG/경제통계01.png'], width=800)
# Out:
# <PIL.Image.Image image mode=RGBA size=800x562 at 0x1FE3C2C39D0>

# %% [markdown]
# ECOS OpenAPI

# %%
nb_setup.images_hconcat(['C:/HSCHUNG/PYTHON/B_CLASS/B_AppliedDataAnalysis/C202102/PNG/경제통계02.png'], width=800)
# Out:
# <PIL.Image.Image image mode=RGBA size=800x558 at 0x1FE3F0C1A00>

# %% [markdown]
# 인증키 신청

# %%
nb_setup.images_hconcat(['C:/HSCHUNG/PYTHON/B_CLASS/B_AppliedDataAnalysis/C202102/PNG/경제통계03.png'], width=800)
# Out:
# <PIL.Image.Image image mode=RGBA size=800x623 at 0x1FE3F0C1CA0>

# %%
nb_setup.images_hconcat(['C:/HSCHUNG/PYTHON/B_CLASS/B_AppliedDataAnalysis/C202102/PNG/경제통계04.png'], width=800)
# Out:
# <PIL.Image.Image image mode=RGBA size=800x402 at 0x1FE3F0C1E50>

# %%
nb_setup.images_hconcat(['C:/HSCHUNG/PYTHON/B_CLASS/B_AppliedDataAnalysis/C202102/PNG/경제통계05.png'], width=800)
# Out:
# <PIL.Image.Image image mode=RGBA size=800x672 at 0x1FE3F0C1DC0>
