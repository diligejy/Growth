# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame(pd.read_excel("rawdata/초등학생_키몸무게.xlsx"))
plt.scatter(df.height, df.weight)
plt.xlabel("height")
plt.ylabel("weight")
plt.show()
