# %% [markdown]
# ### 막대의 수 변화에 따른 히스토그램 작성

# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("rawdata/중학생_남자_키.xlsx")

# %%
plt.hist(df, label='bins=5', bins=5)
plt.legend()
plt.show()

# %%
plt.hist(df, label='bins=7', bins=7)
plt.legend()
plt.show()
