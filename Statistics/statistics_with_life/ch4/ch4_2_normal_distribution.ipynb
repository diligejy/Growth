# %% [markdown]
# ### EX-1
#
# 평균이 50이고 표준편차가 5인 정규분포 그래프 작성

# %%
import numpy as np 
import matplotlib.pyplot as plt 
from scipy.stats import norm

mu = 50
scale = 5

x = np.arange(mu-30, mu + 30, 0.1)
y = norm.pdf(x, mu, scale)

plt.bar(x, y)
plt.xlabel("X")
plt.ylabel("f(X)")
plt.title("Normal Distribution(mu=50, sigma=5)")
plt.show()

# %%
from scipy.stats import norm

mu = 0
sigma = 1

y1 = norm.cdf(0.5, mu, sigma)
y2 = norm.cdf(-1.5, mu, sigma)

print("P(-1.5 <= Z <= 0.5)", y1 - y2)
# Out:
# P(-1.5 <= Z <= 0.5) 0.624655260005155

# %%
# 정규분포 누적분포함수의 역함수 계산

from scipy.stats import norm

mu = 0 
sigma = 1
percent_point = 0.9

print('P(Z<=k) = 0.9, k=', norm.ppf(percent_point, mu, sigma))
# Out:
# P(Z<=k) = 0.9, k= 1.2815515655446004

# %%
# 데이터 정규성 확인
import numpy as np 
import statsmodels.api as sm
import matplotlib.pyplot as plt 

data = np.random.normal(0, 1, 100)
plot = sm.qqplot(data, line='45')
plt.show()

# %%
data
# Out:
# array([-0.46424873,  0.95299334, -0.77320186,  0.18798564,  0.7622945 ,
#        -0.26531137, -1.07530445,  1.18837881, -0.12704534,  2.17460724,
#        -0.3107357 , -0.44138756,  0.06244688, -1.76931303, -1.67833046,
#        -0.71775157, -2.15288087, -1.79274643, -1.61274406,  0.28178601,
#        -0.79209048,  0.13761695,  1.03837332, -0.14451914, -0.91547546,
#        -0.43348121, -1.57673553, -0.44772481, -0.61919045, -1.67493626,
#        -0.39278058, -0.09986705,  0.69397426, -1.00280004, -0.82669703,
#         1.11404506, -1.18953535,  0.49888134, -0.68781302, -0.55455972,
#        -0.8872974 ,  0.39288244, -0.4848401 ,  0.12338437,  0.25524508,
#         1.28409747, -2.75080658, -1.47734792, -0.14233816, -1.90930785,
#        -0.31534534, -1.63849452, -0.43916758, -1.01299926,  0.54085874,
#         2.07873619,  0.38892586,  0.83305093,  0.2378361 , -0.23961534,
#         1.90329305, -1.4588978 , -0.55340733, -0.46427073,  0.0355301 ,
#        -0.74089599, -0.53732448,  0.39040681, -0.21423388,  0.07383111,
#        -0.68016709,  0.1950963 ,  0.25566091,  1.68953935,  0.42076053,
#         0.85357761, -0.84646673,  0.85842928,  1.06054485, -0.53106162,
#        -0.36674003,  0.17249536,  2.60231094,  0.34049768,  0.44103476,
#        -0.62597701, -0.3438077 ,  0.31329394, -0.04001917,  1.05295164,
#         1.32236835, -0.21690481,  1.01219973,  0.14080174, -0.56398314,
#         0.0267076 ,  0.8330452 , -0.71052362,  0.18810066, -0.30342097])
