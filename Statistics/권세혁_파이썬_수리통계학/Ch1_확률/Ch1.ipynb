# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. 기본개념
#
# - 확률변수

# %%
x = [1, 3, 4, 2, 2, 5, 6, 1, 6, 2]
plt.hist(x)
# Out:
# (array([2., 0., 3., 0., 1., 0., 1., 0., 1., 2.]),
#  array([1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. , 5.5, 6. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(x, density=True)
# Out:
# (array([0.4, 0. , 0.6, 0. , 0.2, 0. , 0.2, 0. , 0.2, 0.4]),
#  array([1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. , 5.5, 6. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# - 심슨의 역설
#
#     - 전체 결과와 세부적 결과가 상반될 때
#
#     ![image.png](attachment:image.png)
